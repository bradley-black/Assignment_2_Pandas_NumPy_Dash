# %% [markdown]
# <a href="https://colab.research.google.com/github/bradley-black/Assignment_2_Pandas_NumPy_Dash/blob/main/Assignment_2_Pandas_NumPy_Dash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2 — Exploratory Data Analysis with Pandas, NumPy & Dash
#
# **Course:** Programming for Data Analytics
# **Due:** *(set by instructor)*
# **Student Name:** ____________________________
# **Dataset:** _________________________________
# **Git Repository:** ___________________________
#
# ---
# ## 🎯 Assignment Goal
# This assignment builds directly on **Assignment 1**.
#
# Your goal is to:
# - Use **Pandas and NumPy** to explore and summarize a real dataset
# - Apply **vectorized operations** instead of loops
# - Create meaningful exploratory visualizations
# - Build a **very simple Dash app** to communicate insights
#
# > Focus on understanding and communicating the data, not on complex modeling.

# %% [markdown]
# ## 1) Environment & tools check
#
# Confirm that you have:
# - Anaconda installed
# - Pandas, NumPy, Plotly, Dash installed
# - A Git repository for this project
#
# ### 1.1 Checklist
# - [ ] Pandas
# - [ ] NumPy
# - [ ] Plotly
# - [ ] Dash
# - [ ] Git & GitHub
#
# **Describe any issues encountered:**
# -

# %% [markdown]
# ## 2) Import libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Dash imports (used later)
from dash import Dash, dcc, html

# %% [markdown]
# ## 3) Load the dataset
# Load the dataset selected in Assignment 1.
#
# > Document any assumptions you make when loading the data.

# %%
# TODO: update the path to your dataset
# df = pd.read_csv("your_dataset.csv")
# df.head()

# %% [markdown]
# ## 4) Dataset overview with Pandas

# %%
# Shape, columns, and types
# df.shape
# df.info()

# %% [markdown]
# ### Initial observations
# Write 3–5 observations about the dataset structure.
# -
# -
# -

# %% [markdown]
# ## 5) Descriptive statistics with Pandas & NumPy

# %%
# Pandas summary statistics
# df.describe()

# %%
# NumPy-based statistics (example)
# np.mean(df['column_name'])
# np.median(df['column_name'])
# np.std(df['column_name'])

# %% [markdown]
# ### Interpretation
# What do these statistics tell you about the data distribution?
# -

# %% [markdown]
# ## 6) Missing values & basic transformations

# %%
# Missing values
# df.isna().sum()

# %%
# Example NumPy/Pandas transformation
# df['normalized_column'] = (df['column_name'] - df['column_name'].mean()) / df['column_name'].std()

# %% [markdown]
# ### Data quality notes
# -

# %% [markdown]
# ## 7) Exploratory visualizations (Plotly)

# %%
# Example interactive plot
# fig = px.histogram(df, x='column_name', title='Distribution of column_name')
# fig.show()

# %% [markdown]
# Create at least **3 interactive visualizations** that help answer your  questions.
#
# > Add blockquote

# %% [markdown]
# ## 8) Mini Dash application

# %% [markdown]
# Build a **very simple Dash app** that displays:
# - A title
# - One interactive chart
# - A short description of the insight
#
# > This app does not need callbacks. Keep it simple.

# %%
app = Dash(__name__)

app.layout = html.Div([
    html.H1("My First Dash App"),
    html.P("Describe the insight shown below."),
    # dcc.Graph(figure=fig)
])

# Run the app (uncomment to run)
# app.run_server(debug=True)

# %% [markdown]
# ## 9) Linking back to the problem definition
#
# Based on your EDA and Dash visualization:
# - What new insights emerged?
# - Do you need to refine your original questions?
# -

# %% [markdown]
# ## 10) Final reflection
#
# In 4–6 sentences:
# - What did Pandas and NumPy help you understand?
# - How did Dash change the way you communicate results?
#
# ---
# ### ✅ Submission checklist
# - [ ] Pandas & NumPy used for statistics and transformations
# - [ ] At least 3 interactive visualizations
# - [ ] Simple Dash app created
# - [ ] Clear written interpretations
# - [ ] Notebook committed to Git
